# %%
import cv2
import matplotlib.pyplot as plt
from PIL import Image

# %%
image = cv2.imread(r"C:\Users\91987\Documents\python\Resources\Photos\park.jpg")
image_RGB = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
image_Gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(image_RGB)
plt.show()

# %% [markdown]
# ## Canny

# %%
canny1 = cv2.Canny(image_Gray, 150,175)
canny2 = cv2.Canny(image_Gray,50,150)
plt.imshow(canny1 , cmap = "gray")
plt.show()
plt.imshow(canny2 , cmap = "gray")
plt.show()

# %%
sobelx = cv2.Sobel(image_Gray,cv2.CV_64F,1,0)
sobely = cv2.Sobel(image_Gray,cv2.CV_64F,0,1)
Sobel = cv2.bitwise_or(sobelx,sobely) 

plt.imshow(sobelx , cmap= "gray")
plt.show()
plt.imshow(sobely , cmap = "gray")
plt.show()
plt.imshow(Sobel , cmap = "gray")
plt.show()
# Out:
# c:\Users\91987\anaconda3\envs\torch\lib\site-packages\matplotlib\image.py:484: RuntimeWarning: invalid value encountered in subtract
#   A_scaled -= a_min
